# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('Indian Startup.csv')
print(df.shape)
df.sample(5)
# Out:
# (1209, 10)
#      Company/Brand  Founded Headquarters              Sector  \
# 649          Trell   2016.0    Bangalore     Social commerce
# 156        Inzpira   2021.0   Trivandrum          E-learning
# 1194   Pocket Aces   2013.0       Mumbai               Media
# 558        Toothsi   2018.0       Mumbai              Health
# 1164      Biconomy   2019.0    New Delhi  Blockchain startup
#
#                                            What it does  \
# 649   India's Largest Lifestyle Social Commerce plat...
# 156   Inzpira is India's only Live online 1:1 platfo...
# 1194  Pocket Aces is a digital entertainment company...
# 558   India’s first and largest at home smile makeov...
# 1164  Biconomy is a technology company building tran...
#
#                                               Founder/s  \
# 649   Pulkit Agarwal, Prashant Sachan, Arun Lodhi, B...
# 156                   Rohith Namboothiri, Sruthy Ramesh
# 1194  Anirudh Pandita, Aditi Shrivastava, Ashwin Suresh
# 558   Dr Arpi Mehta, Dr Pravin Shetty, Dr Manjul Jai...
# 1164      Ahmed Al-Balaghi, Aniket Jindal, Sachin Tomar
#
#                                              Investor/s       Amount  \
# 649                                    Mirae Asset, H&M  $45,000,000
# 156                          Raj Nair, Gopinath Latpate     $300,000
# 1194                           3one4 Capital, DSP Group   $2,000,000
# 558   Eight Roads Ventures, Think Investments, Manke...  $20,000,000
# 1164                    Binance Labs, Zee Prime Capital   $1,500,000
#
#          Stage     Date
# 649   Series B  Jul-2021
# 156       Seed  Nov-2021
# 1194       NaN  Jan-2021
# 558   Series B  Aug-2021
# 1164      Seed  Jan-2021

# %%
df["Current Year"] = 2021

# %%
df["Years_Old"] = df["Current Year"] - df["Founded"]

# %%
df.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# 3                                  Vikram Chachra
# 4  Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
#
#                     Investor/s       Amount     Stage     Date   Current Year  \
# 0             Disrupt ADQ, QIC  $35,000,000  Series B  Dec-2021          2021
# 1                 Tiger Global  $40,000,000       NaN  Dec-2021          2021
# 2  Valar Ventures, IA Ventures  $40,000,000  Series B  Dec-2021          2021
# 3                          NaN  $50,000,000       NaN  Dec-2021          2021
# 4        Sequoia Capital India   $4,900,000  Series A  Dec-2021          2021
#
#    Years_Old
# 0        6.0
# 1        9.0
# 2        6.0
# 3        3.0
# 4        0.0

# %%
df = df[["Company/Brand", "Founded", "Headquarters", "Sector", "Founder/s", "Investor/s", "Amount", "Current Year","Years_Old"]]

# %%
df.shape
# Out:
# (1209, 9)

# %%
df.sample(5)
# Out:
#      Company/Brand  Founded Headquarters                            Sector  \
# 933    Solethreads   2018.0     Gurugram                           Fashion
# 3      8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 1048        Qoohoo   2020.0    Bangalore                   Social platform
# 714       Bambinos   2020.0    Bangalore                            EdTech
# 758   BrowserStack   2011.0       Mumbai                      SaaS startup
#
#                              Founder/s                            Investor/s  \
# 933                        Vikram Iyer  DSG Consumer Partners, Saama Capital
# 3                       Vikram Chachra                                   NaN
# 1048  Vimal Singh Rathore, Aseem Gupta                       Angel investors
# 714     Ashish Gupta, Ankit Hetamsaria                          HNIs, Angels
# 758       Nakul Aggarwal, Ritesh Arora                                 Accel
#
#             Amount  Current Year  Years_Old
# 933     $1,000,000          2021        3.0
# 3      $50,000,000          2021        3.0
# 1048      $800,000          2021        1.0
# 714       $500,000          2021        1.0
# 758   $200,000,000          2021       10.0

# %%
sns.pairplot(df)

# %%
city = df["Headquarters"].value_counts().sort_values(ascending=False).head(15)

# %%
sns.barplot(x=city, y = city.index).set_title("Top cities for Startups")
# Out:
# Text(0.5, 1.0, 'Top cities for Startups')

# %%
sect = df["Sector"].value_counts().sort_values(ascending=False).head(15)
sns.barplot(x=sect,y=sect.index).set_title("Top sectors for Startups")
# Out:
# Text(0.5, 1.0, 'Top sectors for Startups')

# %%
df["Amount"] = df["Amount"].str.replace("$",'')
df["Amount"] = df["Amount"].str.replace(",",'')
df['Amount'] = pd.to_numeric(df['Amount'], errors = 'coerce')
df.head()
# Out:
# C:\Users\MrigTen\AppData\Local\Temp\ipykernel_14268\223488789.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Amount"] = df["Amount"].str.replace("$",'')
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# 3                                  Vikram Chachra
# 4  Prachi Dharani, Rohit Sukhija, Yogesh Lokhande
#
#                     Investor/s      Amount  Current Year  Years_Old
# 0             Disrupt ADQ, QIC  35000000.0          2021        6.0
# 1                 Tiger Global  40000000.0          2021        9.0
# 2  Valar Ventures, IA Ventures  40000000.0          2021        6.0
# 3                          NaN  50000000.0          2021        3.0
# 4        Sequoia Capital India   4900000.0          2021        0.0

# %%
invest = df["Investor/s"].value_counts().sort_values(ascending=False).head(15)
sns.barplot(x=invest,y=invest.index).set_title("Top Investor/s for Startups")
# Out:
# Text(0.5, 1.0, 'Top Investor/s for Startups')
